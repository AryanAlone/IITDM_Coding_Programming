# %% [markdown]
# <a href="https://colab.research.google.com/github/AryanAlone/IITDM_Coding_Programming/blob/master/122Me0029_Aryan_A_SIC_Project_IMDB_ratimg_vs_duration_relation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
df=pd.read_csv("/content/imdb.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
df.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
df.head()
# Out:
#    star_rating          title content_rating      genre  duration  \
# 0          7.5  Bad Education          NC-17      Crime       106
# 1          7.8  Donnie Brasco              R  Biography       127
# 2          7.8    The Sandlot             PG     Comedy       101
# 3          7.7  Blood Simple.              R      Crime        99
# 4          7.7          50/50              R     Comedy       100
#
#                                          actors_list
# 0  [u'Gael Garc\xeda Bernal', u'Fele Mart\xednez'...
# 1  [u'Al Pacino', u'Johnny Depp', u'Michael Madsen']
# 2    [u'Tom Guiry', u'Mike Vitar', u'Patrick Renna']
# 3  [u'John Getz', u'Frances McDormand', u'Dan Hed...
# 4  [u'Joseph Gordon-Levitt', u'Seth Rogen', u'Ann...

# %%
display(df)
# Out:
#      star_rating                     title content_rating      genre  \
# 0            7.5             Bad Education          NC-17      Crime
# 1            7.8             Donnie Brasco              R  Biography
# 2            7.8               The Sandlot             PG     Comedy
# 3            7.7             Blood Simple.              R      Crime
# 4            7.7                     50/50              R     Comedy
# ..           ...                       ...            ...        ...
# 974          7.8                 The Birds          PG-13     Horror
# 975          8.5            Apocalypse Now              R      Drama
# 976          7.7             Moulin Rouge!          PG-13      Drama
# 977          7.6           Of Mice and Men          PG-13      Drama
# 978          7.8  The Theory of Everything          PG-13  Biography
#
#      duration                                        actors_list
# 0         106  [u'Gael Garc\xeda Bernal', u'Fele Mart\xednez'...
# ...

# %%
sns.histplot(data=df , x='star_rating')
# Out:
# <Axes: xlabel='star_rating', ylabel='Count'>

# %% [markdown]
# Most movies have got 7.5-7.75 rating and very few make it to the 9.0+ rating

# %%
sns.scatterplot(data=df , x='duration', y='star_rating', hue='genre' )
# Out:
# <Axes: xlabel='duration', ylabel='star_rating'>

# %% [markdown]
# In general most movies lie in the 80-160 minute duration and some of the longer movies have also got higher ratings

# %%
df['genre'].value_counts()
# Out:
# genre
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: count, dtype: int64

# %%
plt.pie(df['genre'].value_counts(), labels=df['genre'].value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7b026fbb9c30>,
# ...
#  [Text(0.690559401763845, 0.856228773538685, 'Drama'),
#   Text(-0.7203468250294089, 0.8313245164615622, 'Comedy'),
#   Text(-1.0964621095255178, -0.088152381560861, 'Action'),
#   Text(-0.6711534366177855, -0.871523415931056, 'Crime'),
#   Text(-0.012354275373648511, -1.0999306213939097, 'Biography'),
#   Text(0.504572064539456, -0.9774492476268991, 'Adventure'),
#   Text(0.872599162768846, -0.6697542094941316, 'Animation'),
#   Text(1.0284697334606816, -0.3901922697277776, 'Horror'),
#   Text(1.0739150063166638, -0.2381313906394535, 'Mystery'),
#   Text(1.0895445082523985, -0.15130355097300066, 'Western'),
#   Text(1.0952403048166697, -0.10221875906646853, 'Sci-Fi'),
#   Text(1.0979560559559636, -0.06702610826853214, 'Thriller'),
#   Text(1.0993147704334387, -0.038820555210815164, 'Film-Noir'),
#   Text(1.0997961156637863, -0.0211779123345034, 'Family'),
#   Text(1.0999490280060602, -0.0105894187056497, 'History'),
# ...

# %%
df1 = df.drop('title', axis=1)
df2 = df1.drop('content_rating', axis=1)
df3 = df2.drop('actors_list', axis=1)
display(df3)
# Out:
#      star_rating      genre  duration
# 0            7.5      Crime       106
# 1            7.8  Biography       127
# 2            7.8     Comedy       101
# 3            7.7      Crime        99
# 4            7.7     Comedy       100
# ..           ...        ...       ...
# 974          7.8     Horror       119
# 975          8.5      Drama       153
# 976          7.7      Drama       127
# 977          7.6      Drama       115
# 978          7.8  Biography       123
#
# [979 rows x 3 columns]

# %%
df4=df3.groupby(['genre']).agg({'duration': 'mean','star_rating' : 'mean'})
display(df4)
# Out:
#              duration  star_rating
# genre
# Action     126.485294     7.884559
# Adventure  134.840000     7.933333
# Animation   96.596774     7.914516
# Biography  131.844156     7.862338
# Comedy     107.602564     7.822436
# Crime      122.298387     7.916935
# Drama      126.539568     7.902518
# Family     107.500000     7.850000
# Fantasy    112.000000     7.700000
# Film-Noir   97.333333     8.033333
# History     66.000000     8.000000
# Horror     102.517241     7.806897
# Mystery    115.625000     7.975000
# Sci-Fi     109.000000     7.920000
# Thriller   114.200000     7.680000
# Western    136.666667     8.255556

# %%
sns.scatterplot(data=df4, x='duration', y='star_rating' , hue='genre')
# Out:
# <Axes: xlabel='duration', ylabel='star_rating'>

# %% [markdown]
# As we can see the most rated movies lie in the 'Action' genre and the same are also generally the longest in duration
